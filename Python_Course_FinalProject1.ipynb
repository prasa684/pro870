# %%
#import the basic libraries related to DS and Ml in python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#This project deals with the perfromance evaluation of an employee
# scores of the  employees are retrieved without  any further personal informations abt them 


employeeValue = pd.read_csv("EmployeePerformance.csv")
employeeValue
# Out:
#      gender Categoryofjob  Level of education         lunch  \
# 0    female       group B   bachelor's degree      standard
# 1    female       group C        some college      standard
# 2    female       group B     master's degree      standard
# 3      male       group A  associate's degree  free/reduced
# 4      male       group C        some college      standard
# ..      ...           ...                 ...           ...
# 995  female       group E     master's degree      standard
# 996    male       group C         high school  free/reduced
# 997  female       group C         high school  free/reduced
# 998  female       group D        some college      standard
# 999  female       group D        some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ...

# %%
employeeValue.head()
# Out:
#    gender Categoryofjob  Level of education         lunch  \
# 0  female       group B   bachelor's degree      standard
# 1  female       group C        some college      standard
# 2  female       group B     master's degree      standard
# 3    male       group A  associate's degree  free/reduced
# 4    male       group C        some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
employeeValue.info() ## fetch the column names of a table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   1000 non-null   object
#  1   Categoryofjob            1000 non-null   object
#  2    Level of education      1000 non-null   object
#  3   lunch                    1000 non-null   object
#  4   test preparation course  1000 non-null   object
#  5   math score               1000 non-null   int64
#  6   reading score            1000 non-null   int64
#  7   writing score            1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
employeeValue.shape
# Out:
# (1000, 8)

# %%
employeeValue['Categoryofjob'].value_counts()
# Out:
# Categoryofjob
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
employeeValue['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
employeeValue['math score'].value_counts(normalize=True)
employeeValue['math score'].value_counts(dropna=False).plot.bar(figsize=(18,5),color='blue')
plot.xlabel('All math scores')
plot.ylabel('Math score value')
# Out:
# Text(0, 0.5, 'Math score value')
